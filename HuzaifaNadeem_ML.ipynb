# %% [markdown]
# ## Machine Learning - Data Fundamentals Final Project

# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
import pyarrow

# %% [markdown]
# ### Part 1 - Chart a Straight Line

# %%
# %matplotlib inline
c = lambda f: 5 / 9 * (f - 32)

# %%
temps = [(f, c(f)) for f in range(0, 101, 10)]

# %%
temps_df = pd.DataFrame(temps, columns=['Fahrenheit', 'Celsius'])

# %%
axes = temps_df.plot(x='Fahrenheit', y='Celsius', style='.-')

y_label = axes.set_ylabel('Celsius')

# %%
# import and preview NYC temperature data
nyc = pd.read_csv('ave_hi_nyc_jan_1895-2018.csv')
nyc.head()
# Out:
#      Date  Value  Anomaly
# 0  189501   34.2     -3.2
# 1  189601   34.7     -2.7
# 2  189701   35.5     -1.9
# 3  189801   39.6      2.2
# 4  189901   36.4     -1.0

# %%
nyc.tail()
# Out:
#        Date  Value  Anomaly
# 119  201401   35.5     -1.9
# 120  201501   36.1     -1.3
# 121  201601   40.8      3.4
# 122  201701   42.8      5.4
# 123  201801   38.7      1.3

# %%
nyc.columns = ['Date', 'Temperature', 'Anomaly']

# %%
nyc.head(3)
# Out:
#      Date  Temperature  Anomaly
# 0  189501         34.2     -3.2
# 1  189601         34.7     -2.7
# 2  189701         35.5     -1.9

# %%
nyc.Date.dtype
nyc.Date = nyc.Date.floordiv(100)

# %%
nyc.head(3)
# Out:
#    Date  Temperature  Anomaly
# 0  1895         34.2     -3.2
# 1  1896         34.7     -2.7
# 2  1897         35.5     -1.9

# %%
pd.options.display.precision = 2

# %%
nyc.Temperature.describe()
# Out:
# count    124.00
# mean      37.60
# std        4.54
# min       26.10
# 25%       34.58
# 50%       37.60
# 75%       40.60
# max       47.60
# Name: Temperature, dtype: float64

# %% [markdown]
# ### Part 2: Prediction

# %%
from scipy import stats

# %%
# set up linear regression, get slope
linear_regression = stats.linregress(x=nyc.Date, y=nyc.Temperature)
linear_regression.slope
# Out:
# np.float64(0.014771361132966163)

# %%
# get y-intercept
linear_regression.intercept
# Out:
# np.float64(8.694993233674289)

# %%
linear_regression.slope * 2019 + linear_regression.intercept
# Out:
# np.float64(38.51837136113297)

# %%
linear_regression.slope * 2024 + linear_regression.intercept
# Out:
# np.float64(38.5922281667978)

# %%
linear_regression.slope * 1850 + linear_regression.intercept
# Out:
# np.float64(36.022011329661694)

# %%
sns.set_style('whitegrid')

# %%
axes = sns.regplot(x=nyc.Date, y=nyc.Temperature)

axes.set_ylim(10, 70)
# Out:
# (10.0, 70.0)

# %% [markdown]
# ### Part 3 - Prediction

# %%
from sklearn.model_selection import train_test_split

# %%
# split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
     nyc.Date.values.reshape(-1, 1), nyc.Temperature.values, 
     random_state=11)

# %%
X_train.shape
# Out:
# (93, 1)

# %%
X_test.shape
# Out:
# (31, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regression = LinearRegression()

# %%
# fit the model to the training data
linear_regression.fit(X=X_train, y=y_train)
# Out:
# LinearRegression()

# %%
linear_regression.coef_
# Out:
# array([0.01939167])

# %%
linear_regression.intercept_
# Out:
# np.float64(-0.30779820252656975)

# %%
# test the model on the test data
predicted = linear_regression.predict(X_test)

# %%
expected = y_test

# %%
# plot the predicted values against the expected values for first 6 values
for p, e in zip(predicted[::5], expected[::5]):
     print(f'predicted: {p:.2f}, expected: {e:.2f}')
# Out:
# predicted: 37.86, expected: 31.70
# predicted: 38.69, expected: 34.80
# predicted: 37.00, expected: 39.40
# predicted: 37.25, expected: 45.70
# predicted: 38.05, expected: 32.30
# predicted: 37.64, expected: 33.80
# predicted: 36.94, expected: 39.70

# %%
# lambda function to return the predicted values, based on the linear regression model using coef as m and intercept as b
predict = (lambda x: linear_regression.coef_ * x + linear_regression.intercept_)

# %%
predict(2020)
# Out:
# array([38.86338185])

# %%
predict(1890)
# Out:
# array([36.34246432])

# %%
predict(2025)
# Out:
# array([38.96034022])

# %%
predict(2024)
# Out:
# array([38.94094855])

# %%
predict(2035)
# Out:
# array([39.15425695])

# %%
axes = sns.scatterplot(data=nyc, x='Date', y='Temperature',
     hue='Temperature', palette='winter', legend=False)

axes.set_ylim(10, 70)

x = np.array([min(nyc.Date.values), max(nyc.Date.values)])

y = predict(x)

line = plt.plot(x, y)

# %% [markdown]
# #### Insights

# %% [markdown]
# Both methods are effective, but Scikit-learn offers superior testing capabilities and is more suitable for complex projects.
#
# For quick and straightforward machine learning tasks, SciPy is highly efficient. However, for more detailed, intricate, or precise projects, I would prefer using Scikit-learn's model.
